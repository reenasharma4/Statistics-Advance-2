# %% [markdown]
# #Statics Advance 2

# %% [markdown]
# #1. What is hypothesis testing in statistics?
#   - Hypothesis testing is just a structured way of making decisions based on data. It involves testing an assumption about the population parameter and determine on the basis of that whether there is enough evidence to reject or fail to reject that assumption.
#
# #2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
#   - Null Hypothesis (H0): This is a "nothing special" hypothesis or it represents the default. It says that there is no difference, no change, no effect or relationship between the variables.
#
#   Example: A new weight loss pill does not help people to lose their weight.
#
#   - Alternative Hypothesis (H1 or H1): It is the opposite of the null hypothesis. It suggest that something is happening and says that there is a difference, change, effect or relationship.
#
#   Example: The new weight loss pill does help people to lose their weight.
#
# #3. What is the significance level in hypothesis testing, and why is it important?
#   - It is a threshold for determining whether to reject the null hypothesis or not. It represents the possibility of making the wrong decision or type I error.
#   - Common significance levels are 0.05 (5%) or 0.01 (1%).
#   - A lower α reduces the risk of a type error I but increases the risk of a type error II.
#
#   The significance level helps define the cutoff point for decision-making in hypothesis testing.
#
# #4. What does a P-value represent in hypothesis testing?
#   - In hypothesis testing, the P-value is a measure that helps to determine the strength of evidence against the null hypothesis (H0). It represents the probability of obtaining the observed results (or more extreme ones) if H0 were true.
#   - Interpretation of P-Value:
#     * Small P-value (P<0.05): Strong evidence against H0, suggesting that we reject the null hypothesis and accept the alternative hypothesis (H1).
#     * Large P-value (P>0.05): Weak evidence against H0, meaning we do not have enough proof to reject the null hypothesis.
#
# #5. How do you interpret the P-value in hypothesis testing?
#   - If P≤α (e.g., 0.05 or 0.01): Reject H0. The result is statistically significant, meaning there is enough evidence to support H1.
#   - If P>α: Fail to reject H0. There is not enough evidence to support H1, meaning we do not have strong proof that the null hypothesis is false.
#
#   Example Interpretation:
#     * A P-value of 0.03 (with α=0.05) → Reject H0, significant result.
#     * A P-value of 0.08 (with α=0.05) → Fail to reject H0, not significant.
#
# #6. What are Type 1 and Type 2 errors in hypothesis testing?
#   - Imagine you are testing whether a medicine works.
#     1. Type 1 Error (False Positive): Saying the medicine works when it actually does not.
#     2. Type 2 Error (False Negative): Saying the medicine does not work when it actually does.
#
# In simpler terms, Type 1 error is like a false alarm, and Type 2 error is like missing a real issue.
#
# #7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#    - One-tailed test: Checks if something is either greater or lesser than a certain value (not both). For Example: Checking if a new diet helps people lose more weight than before.
#    - Two-tailed test: Checks if something is different (either greater or lesser). For Example: Checking if a new drug affects blood pressure either positively or negatively.
#
# #8. What is the Z-test, and when is it used in hypothesis testing?
#   - A Z-test is used when we compare a sample to a known population and we know the standard deviation. For Example: If a company claims the average salary of employees is $50,000, we use a Z-test to check if our sample data supports this claim.
#
# #9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
#    - The Z-score formula: Z=X-𝜇/σ
#    - Where:
#      1. X = Sample value
#      2. μ = Mean (average)
#      3. σ = Standard deviation
#    - A Z-score tells us how far a value is from the average in terms of standard deviations.
#      1. High Z-score: Value is far from the average.
#      2. Low Z-score: Value is close to the average.
#
# #10. What is the T-distribution, and when should it be used instead of the normal distribution?
#    - The T-distribution is used when we do not know the populations standard deviation and have a small sample size. For Example: If we test the average height of 10 students in a school, we use the T-distribution instead of the normal distribution.
#
# #11. What is the difference between a Z-test and a T-test?
#    - Feature	           -   Z-test	              -   T-test
#    - Sample size	       -   Large (≥ 30)	        -   Small (< 30)
#    - Standard deviation	 -   Known	              -     Unknown
#    - Distribution used	 -   Normal distribution	-     T-distribution
#
# #12. What is the T-test, and how is it used in hypothesis testing?
#    - A T-test is used to compare the means of two groups when we do not know the populations standard deviation. For Example: Testing if students in one class score differently than students in another class.
#
# #13. What is the relationship between Z-test and T-test in hypothesis testing?
#    - Both tests compare the sample data to a population, but:
#      1. Z-test is used for large samples and when the standard deviation is known.
#      2. T-test is used for small samples and when the standard deviation is unknown.
#
# #14. What is a confidence interval, and how is it used to interpret statistical results?
#    - A confidence interval gives us a range where the true value is likely to fall. For Example: If we say the average height is 170 cm ± 5 cm (95% confidence), we are 95% sure the true average is between 165 cm and 175 cm.
#
# #15. What is the margin of error, and how does it affect the confidence interval?
#    - The margin of error tells us how much uncertainty is in our estimate.
#      1. A smaller margin of error = More precise results.
#      2. A larger margin of error = Less precise results.
#
#        * Example: Margin of error = 2 cm → Average height = 170 ± 2 cm
#        * Margin of error = 5 cm → Average height = 170 ± 5 cm
#   - Smaller numbers mean a more accurate prediction.
#
# #16. How is Bayes' Theorem used in statistics, and what is its significance?
#    - Bayes' Theorem helps to update probabilities based on the new information. For Example: If a medical test is 90% accurate, but only 1 in 1,000 people have the disease, Bayes' Theorem helps us to calculate the actual chance of having the disease after testing positive.
#
# #17. What is the Chi-square distribution, and when is it used?
#    - The Chi-square distribution is used to analyze the categorical data (data in groups). For Example: Checking if gender and favorite color are related.
#
# #18. What is the Chi-square goodness of fit test, and how is it applied?
#    - The Chi-square goodness of fit test checks if a dataset matches an expected pattern or not. For Example:
#      1. A company expects 50% of customers to prefer Brand A and 50% to prefer Brand B.
#      2. If a survey shows 60% prefer Brand A, we use the Chi-square test to check if this difference is significant.
#
# #19. What is the F-distribution, and when is it used in hypothesis testing?
#    - The F-distribution is used to compare the variances of two datasets. For Example: Checking if the performance of the students in two different schools has the same variation in marks.
#
# #20. What is an ANOVA test, and what are its assumptions?
#    - ANOVA (Analysis of Variance) is used to compare the three or more groups. For Example: Comparing the average test scores of students in three different schools.
#    - Assumptions of ANOVA:
#      1. Data follows a normal distribution.
#      2. The samples are independent.
#      3. The variances of the groups should be equal.
#
# #21. What are the different types of ANOVA tests?
#    - One-way ANOVA: Compares one factor across multiple groups. For example: Comparing students test scores in three schools.
#    - Two-way ANOVA: Compares two factors at once. For Example: Checking how gender and study habits affect test scores.
#
# #22. What is the F-test, and how does it relate to hypothesis testing?
#    - An F-test compares two or more groups to check if they have equal variances or not. For example: Checking if two brands of batteries last for the same amount of time or if one lasts significantly longer.

# %%
#1. Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results.
import numpy as np
import scipy.stats as stats

def z_test(sample, population_mean, population_std, alpha=0.05):
    sample_mean = np.mean(sample)
    sample_size = len(sample)

    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    if p_value < alpha:
        result = "Reject the null hypothesis: The sample mean significantly differs from the population mean."
    else:
        result = "Fail to reject the null hypothesis: No significant difference between sample and population means."

    return z_score, p_value, result

sample_data = [100, 102, 98, 97, 101, 99, 103, 105, 96, 100]
population_mean = 98
population_std = 3

z_score, p_value, interpretation = z_test(sample_data, population_mean, population_std)
print(f"Z-score: {z_score:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Interpretation: {interpretation}")
# Out:
# Z-score: 2.21
# P-value: 0.0269
# Interpretation: Reject the null hypothesis: The sample mean significantly differs from the population mean.

# %%
#2. Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python.
import numpy as np
import scipy.stats as stats

np.random.seed(42)
sample = np.random.normal(loc=50, scale=10, size=30)  # Mean=50, Std=10, Sample size=30

pop_mean = 50
t_stat, p_value = stats.ttest_1samp(sample, pop_mean)

print(f"T-statistic: {t_stat}, P-value: {p_value}")
# Out:
# T-statistic: -1.145017367038331, P-value: 0.2615641461880146

# %%
#3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean.
from statsmodels.stats.weightstats import ztest

np.random.seed(42)
sample = np.random.normal(loc=50, scale=10, size=30)  # Sample drawn from a normal distribution

pop_mean = 50  # Hypothesized population mean

z_stat, p_value = ztest(sample, value=pop_mean)

print(f"Z-statistic: {z_stat}, P-value: {p_value}")
# Out:
# Z-statistic: -1.145017367038331, P-value: 0.25220196328281963

# %%
#4. Perform a two-tailed Z-test using Python and visualize the decision region on a plot.
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

alpha = 0.05

z_critical = stats.norm.ppf(1 - alpha/2)

x = np.linspace(-4, 4, 1000)
y = stats.norm.pdf(x)

plt.figure(figsize=(8, 5))
sns.lineplot(x, y, label="Standard Normal Distribution")

plt.fill_between(x, y, where=(x <= -z_critical) | (x >= z_critical), color='red', alpha=0.3, label="Rejection Region")

z_stat, _ = ztest(sample, value=pop_mean)

plt.axvline(z_stat, color='blue', linestyle='dashed', label=f"Sample Z = {z_stat:.2f}")

plt.axvline(-z_critical, color='red', linestyle='dotted', label=f"Critical Z = {-z_critical:.2f}")
plt.axvline(z_critical, color='red', linestyle='dotted', label=f"Critical Z = {z_critical:.2f}")

plt.legend()
plt.title("Two-Tailed Z-Test Decision Region")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-3a252099e3b7> in <cell line: 0>()
#      12
#      13 plt.figure(figsize=(8, 5))
# ---> 14 sns.lineplot(x, y, label="Standard Normal Distribution")
#      15
#      16 plt.fill_between(x, y, where=(x <= -z_critical) | (x >= z_critical), color='red', alpha=0.3, label="Rejection Region")
#
# TypeError: lineplot() takes from 0 to 1 positional arguments but 2 were given

# %%
#5. Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing.
def visualize_type_errors():
    x = np.linspace(-4, 4, 1000)
    y = stats.norm.pdf(x)

    plt.figure(figsize=(8, 5))
    sns.lineplot(x, y, label="Standard Normal Distribution")

    alpha = 0.05
    z_critical = stats.norm.ppf(1 - alpha/2)

    # Shade Type 1 error region
    plt.fill_between(x, y, where=(x <= -z_critical) | (x >= z_critical), color='red', alpha=0.3, label="Type 1 Error (α)")

    # Shade Type 2 error region
    beta_region = (-1.5, 1.5)
    plt.fill_between(x, y, where=(x > beta_region[0]) & (x < beta_region[1]), color='blue', alpha=0.3, label="Type 2 Error (β)")

    plt.axvline(-z_critical, color='red', linestyle='dotted', label=f"Critical Z = {-z_critical:.2f}")
    plt.axvline(z_critical, color='red', linestyle='dotted', label=f"Critical Z = {z_critical:.2f}")

    plt.legend()
    plt.title("Type 1 and Type 2 Errors in Hypothesis Testing")
    plt.show()

visualize_type_errors()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-a70440cd3957> in <cell line: 0>()
#      24     plt.show()
#      25
# ---> 26 visualize_type_errors()
#
# <ipython-input-15-a70440cd3957> in visualize_type_errors()
#       5
#       6     plt.figure(figsize=(8, 5))
# ----> 7     sns.lineplot(x, y, label="Standard Normal Distribution")
#       8
#       9     alpha = 0.05
#
# TypeError: lineplot() takes from 0 to 1 positional arguments but 2 were given

# %%
#6. Write a Python program to perform an independent T-test and interpret the results.
import numpy as np
import scipy.stats as stats

def independent_t_test():
    np.random.seed(42)
    sample1 = np.random.normal(50, 10, 30)  # Random sample
    sample2 = np.random.normal(55, 10, 30)  # Another random sample

    t_stat, p_value = stats.ttest_ind(sample1, sample2)
    print(f"Independent T-test: t-statistic = {t_stat:.4f}, p-value = {p_value:.4f}")

independent_t_test()
# Out:
# Independent T-test: t-statistic = -2.3981, p-value = 0.0197

# %%
#7. Perform a paired sample T-test using Python and visualize the comparison results.
import seaborn as sns
import matplotlib.pyplot as plt

def paired_t_test():
    np.random.seed(42)
    sample1 = np.random.normal(50, 10, 30)
    sample2 = sample1 + np.random.normal(2, 5, 30)  # Paired sample with slight variation

    t_stat, p_value = stats.ttest_rel(sample1, sample2)
    print(f"Paired T-test: t-statistic = {t_stat:.4f}, p-value = {p_value:.4f}")

    sns.histplot([sample1, sample2], kde=True)
    plt.title("Paired Sample Comparison")
    plt.show()

paired_t_test()
# Out:
# Paired T-test: t-statistic = -1.6403, p-value = 0.1118

# %%
#8. Simulate data and perform both Z-test and T-test, then compare the results using Python.
from statsmodels.stats.weightstats import ztest

def compare_z_t_test():
    np.random.seed(42)
    sample1 = np.random.normal(50, 10, 100)
    sample2 = np.random.normal(52, 10, 100)

    t_stat, t_p = stats.ttest_ind(sample1, sample2)
    z_stat, z_p = ztest(sample1, sample2)

    print(f"T-test: t-statistic = {t_stat:.4f}, p-value = {t_p:.4f}")
    print(f"Z-test: z-statistic = {z_stat:.4f}, p-value = {z_p:.4f}")

compare_z_t_test()
# Out:
# T-test: t-statistic = -2.4766, p-value = 0.0141
# Z-test: z-statistic = -2.4766, p-value = 0.0133

# %%
#9. Write a Python function to calculate the confidence interval for a sample mean and explain its significance.
def confidence_interval():
    np.random.seed(42)
    sample = np.random.normal(50, 10, 100)

    mean = np.mean(sample)
    sem = stats.sem(sample)
    interval = stats.t.interval(0.95, len(sample)-1, loc=mean, scale=sem)

    print(f"95% Confidence Interval: {interval}")

confidence_interval()
# Out:
# 95% Confidence Interval: (np.float64(47.159531636381004), np.float64(50.76353801573714))

# %%
#10. Write a Python program to calculate the margin of error for a given confidence level using sample data.
def margin_of_error():
    np.random.seed(42)
    sample = np.random.normal(50, 10, 100)

    sem = stats.sem(sample)
    margin = sem * stats.t.ppf((1 + 0.95) / 2., len(sample)-1)

    print(f"Margin of Error: {margin:.4f}")

margin_of_error()
# Out:
# Margin of Error: 1.8020

# %%
#11. Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process.
def bayesian_inference(prior, likelihood, evidence):
    posterior = (likelihood * prior) / evidence
    print(f"Bayesian Inference - Posterior Probability: {posterior:.4f}")

bayesian_inference(0.5, 0.7, 0.8)
# Out:
# Bayesian Inference - Posterior Probability: 0.4375

# %%
#12. Perform a Chi-square test for independence between two categorical variables in Python.
def chi_square_test():
    observed = np.array([[30, 10], [20, 40]])
    chi2, p, _, _ = stats.chi2_contingency(observed)

    print(f"Chi-Square Test: Chi2 = {chi2:.4f}, p-value = {p:.4f}")

chi_square_test()
# Out:
# Chi-Square Test: Chi2 = 15.0417, p-value = 0.0001
# /usr/local/lib/python3.11/dist-packages/IPython/core/inputtransformer2.py:478: UserWarning: `make_tokens_by_line` received a list of lines which do not have lineending markers ('\n', '\r', '\r\n', '\x0b', '\x0c'), behavior will be unspecified
#   warnings.warn("`make_tokens_by_line` received a list of lines which do not have lineending markers ('\\n', '\\r', '\\r\\n', '\\x0b', '\\x0c'), behavior will be unspecified")

# %%
#13. Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data.
def expected_frequencies():
    observed = np.array([[30, 10], [20, 40]])
    _, _, _, expected = stats.chi2_contingency(observed)

    print(f"Expected Frequencies:\n{expected}")

expected_frequencies()
# Out:
# Expected Frequencies:
# [[20. 20.]
#  [30. 30.]]

# %%
#14. Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution.
def goodness_of_fit_test():
    observed = np.array([50, 30, 20])
    expected = np.array([40, 40, 20])

    chi2, p = stats.chisquare(observed, expected)

    print(f"Goodness-of-Fit Test: Chi2 = {chi2:.4f}, p-value = {p:.4f}")

goodness_of_fit_test()
# Out:
# Goodness-of-Fit Test: Chi2 = 5.0000, p-value = 0.0821

# %%
#15. Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics.
def chi_square_distribution():
    data = np.random.chisquare(df=5, size=1000)

    sns.histplot(data, kde=True)
    plt.title("Chi-Square Distribution (df=5)")
    plt.show()

chi_square_distribution()

# %%
#16. D Implement an F-test using Python to compare the variances of two random samples.
def f_test():
    np.random.seed(42)
    sample1 = np.random.normal(50, 10, 30)
    sample2 = np.random.normal(50, 15, 30)

    f_stat = np.var(sample1, ddof=1) / np.var(sample2, ddof=1)
    p_value = stats.f.cdf(f_stat, len(sample1)-1, len(sample2)-1)

    print(f"F-test: F-statistic = {f_stat:.4f}, p-value = {p_value:.4f}")

f_test()
# Out:
# F-test: F-statistic = 0.4153, p-value = 0.0104
# /usr/local/lib/python3.11/dist-packages/IPython/core/inputtransformer2.py:478: UserWarning: `make_tokens_by_line` received a list of lines which do not have lineending markers ('\n', '\r', '\r\n', '\x0b', '\x0c'), behavior will be unspecified
#   warnings.warn("`make_tokens_by_line` received a list of lines which do not have lineending markers ('\\n', '\\r', '\\r\\n', '\\x0b', '\\x0c'), behavior will be unspecified")

# %%
#17. Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results.
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

def anova_test():
    data = pd.DataFrame({
        "Group": np.repeat(["A", "B", "C"], 10),
        "Score": np.concatenate([np.random.normal(50, 10, 10),
                                 np.random.normal(55, 10, 10),
                                 np.random.normal(60, 10, 10)])
    })

    model = ols('Score ~ C(Group)', data=data).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)
    print(anova_table)

    sns.boxplot(x="Group", y="Score", data=data)
    plt.title("One-Way ANOVA")
    plt.show()

anova_test()
# Out:
#                sum_sq    df         F    PR(>F)
# C(Group)   628.803403   2.0  2.987569  0.067281
# Residual  2841.389047  27.0       NaN       NaN

# %%
#18. Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results.
def two_way_anova():
    data = pd.DataFrame({
        "Factor1": np.tile(["X", "Y"], 15),
        "Factor2": np.repeat(["A", "B", "C"], 10),
        "Score": np.random.normal(50, 10, 30)
    })

    model = ols('Score ~ C(Factor1) + C(Factor2) + C(Factor1):C(Factor2)', data=data).fit()
    anova_table = sm.stats.anova_lm(model, typ=2)
    print(anova_table)

    sns.boxplot(x="Factor1", y="Score", hue="Factor2", data=data)
    plt.title("Two-Way ANOVA")
    plt.show()

two_way_anova()
# Out:
#                             sum_sq    df         F    PR(>F)
# C(Factor1)               16.442838   1.0  0.176390  0.678230
# C(Factor2)               42.480978   2.0  0.227857  0.797941
# C(Factor1):C(Factor2)    99.110012   2.0  0.531601  0.594424
# Residual               2237.242275  24.0       NaN       NaN

# %%
#19. Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVAD.
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

def check_anova_assumptions(data, group_column, value_column):
    groups = [group[value_column].values for _, group in data.groupby(group_column)]

    # 1. Normality check (Shapiro-Wilk test)
    for i, group in enumerate(groups):
        stat, p = stats.shapiro(group)
        print(f"Group {i+1} - Shapiro-Wilk Test: p-value = {p:.4f}")

    # Q-Q Plot
    plt.figure(figsize=(6,4))
    for i, group in enumerate(groups):
        stats.probplot(group, dist="norm", plot=plt)
    plt.title("Q-Q Plot for Normality Check")
    plt.show()

    # 2. Homogeneity of variance (Levene’s Test)
    stat, p = stats.levene(*groups)
    print(f"Levene’s Test for Equal Variance: p-value = {p:.4f}")

    # 3. Boxplot for variance comparison
    plt.figure(figsize=(6,4))
    sns.boxplot(x=data[group_column], y=data[value_column])
    plt.title("Boxplot for Variance Comparison")
    plt.show()

# %%
#20. Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results.
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Example dataset
data = pd.DataFrame({
    "Factor1": np.random.choice(["A", "B"], 30),
    "Factor2": np.random.choice(["X", "Y"], 30),
    "Value": np.random.randn(30) + 5
})

# Performing Two-way ANOVA
model = ols("Value ~ C(Factor1) + C(Factor2) + C(Factor1):C(Factor2)", data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print(anova_table)

# Visualization
sns.boxplot(x="Factor1", y="Value", hue="Factor2", data=data)
plt.title("Two-Way ANOVA Visualization")
plt.show()
# Out:
#                           sum_sq    df         F    PR(>F)
# C(Factor1)              0.791724   1.0  0.970273  0.333691
# C(Factor2)              1.478355   1.0  1.811753  0.189918
# C(Factor1):C(Factor2)   1.907884   1.0  2.338148  0.138316
# Residual               21.215499  26.0       NaN       NaN

# %%
#21. Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing.
x = np.linspace(0, 5, 100)
dfn, dfd = 5, 20  # Example degrees of freedom
y = stats.f.pdf(x, dfn, dfd)

plt.plot(x, y, label=f'F-distribution (dfn={dfn}, dfd={dfd})')
plt.title("F-Distribution Curve")
plt.xlabel("F-value")
plt.ylabel("Density")
plt.legend()
plt.show()

# %%
#22. Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means.
from scipy.stats import f_oneway

# Simulated data
group1 = np.random.normal(5, 1, 30)
group2 = np.random.normal(6, 1, 30)
group3 = np.random.normal(7, 1, 30)

# ANOVA test
stat, p = f_oneway(group1, group2, group3)
print(f"One-Way ANOVA: p-value = {p:.4f}")

# Boxplot visualization
plt.boxplot([group1, group2, group3], labels=["Group1", "Group2", "Group3"])
plt.title("One-Way ANOVA Boxplot")
plt.show()
# Out:
# One-Way ANOVA: p-value = 0.0000
# <ipython-input-36-767f1eefeedb>:14: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group1, group2, group3], labels=["Group1", "Group2", "Group3"])

# %%
#23. Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means.
sample = np.random.normal(10, 2, 50)
t_stat, p_val = stats.ttest_1samp(sample, popmean=10)
print(f"T-test: t-statistic = {t_stat:.4f}, p-value = {p_val:.4f}")
# Out:
# T-test: t-statistic = -0.0969, p-value = 0.9232

# %%
#24. Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results.
n = 30
sample_var = np.var(np.random.normal(10, 3, n), ddof=1)
pop_var = 9  # Assumed population variance
chi2_stat = (n - 1) * sample_var / pop_var
p_val = 1 - stats.chi2.cdf(chi2_stat, df=n-1)
print(f"Chi-Square Test: Test statistic = {chi2_stat:.4f}, p-value = {p_val:.4f}")
# Out:
# Chi-Square Test: Test statistic = 18.1191, p-value = 0.9418

# %%
#25. Write a Python script to perform a Z-test for comparing proportions between two datasets or groups.
from statsmodels.stats.proportion import proportions_ztest

count = np.array([40, 30])
nobs = np.array([100, 100])
z_stat, p_val = proportions_ztest(count, nobs)
print(f"Z-Test: z-statistic = {z_stat:.4f}, p-value = {p_val:.4f}")
# Out:
# Z-Test: z-statistic = 1.4825, p-value = 0.1382

# %%
#26. Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results.
var1 = np.var(np.random.normal(10, 3, 30), ddof=1)
var2 = np.var(np.random.normal(10, 2, 30), ddof=1)
F_stat = var1 / var2
dfn, dfd = 29, 29
p_value = 1 - stats.f.cdf(F_stat, dfn, dfd)
print(f"F-Test: F-statistic = {F_stat:.4f}, p-value = {p_value:.4f}")
# Out:
# F-Test: F-statistic = 0.7673, p-value = 0.7599

# %%
#27. Perform a Chi-square test for goodness of fit with simulated data and analyze the results.
observed = np.array([50, 30, 20])
expected = np.array([40, 40, 20])
chi2_stat, p_val = stats.chisquare(observed, expected)
print(f"Chi-Square Goodness of Fit: chi2-stat = {chi2_stat:.4f}, p-value = {p_val:.4f}")
# Out:
# Chi-Square Goodness of Fit: chi2-stat = 5.0000, p-value = 0.0821
